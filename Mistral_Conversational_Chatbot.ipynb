# %%
# !pip install -q transformers accelerate sentencepiece bitsandbytes

# %%
from huggingface_hub import login
login()

# %%
# !pip install -U bitsandbytes>=0.46.1

import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig

model_name = "mistralai/Mistral-7B-Instruct-v0.2"

# Define the quantization configuration
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4", # or "fp4"
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_use_double_quant=True,
)

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto",
    torch_dtype=torch.float16,
    quantization_config=bnb_config # Pass the quantization config here
)
# Out:
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]

# %%
conversation_history = []

def chat(user_input):
    conversation_history.append(f"User: {user_input}")

    prompt = "\n".join(conversation_history) + "\nAssistant:"

    inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

    output = model.generate(
        **inputs,
        max_new_tokens=200,
        temperature=0.7,
        top_p=0.9,
        do_sample=True
    )

    response = tokenizer.decode(output[0], skip_special_tokens=True)
    assistant_reply = response.split("Assistant:")[-1].strip()

    conversation_history.append(f"Assistant: {assistant_reply}")

    return assistant_reply

# %%
print(chat("Can you please help me with scope of RAG?"))
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Absolutely, I'd be happy to help clarify the scope of RAG (Risk, Assess, Govern) in the context of IT Service Management.
#
# RAG is a methodology used in IT Service Management to identify, assess, and manage risks associated with IT services. The primary objective is to ensure that the risks are within acceptable levels and are continually monitored and managed.
#
# The scope of RAG includes:
#
# 1. **Risk Identification**: This is the first step where potential risks are identified. These risks can be internal (e.g., lack of skills, inadequate resources) or external (e.g., cyber threats, natural disasters).
#
# 2. **Risk Assessment**: Once risks are identified, they are assessed based on their likelihood and impact. This helps prioritize risks and determine which ones require immediate attention.
#
# 3. **Risk Governance**: This is the ongoing process of
