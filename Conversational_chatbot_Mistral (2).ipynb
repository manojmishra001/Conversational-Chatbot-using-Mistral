# %%
# !pip install -q transformers accelerate sentencepiece bitsandbytes

# %%
from huggingface_hub import login
login()

# %%
# !pip install -U bitsandbytes>=0.46.1

import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig

model_name = "mistralai/Mistral-7B-Instruct-v0.2"

# Define the quantization configuration
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4", # or "fp4"
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_use_double_quant=True,
)

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto",
    torch_dtype=torch.float16,
    quantization_config=bnb_config # Pass the quantization config here
)
# Out:
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]

# %%
conversation_history = []

def chat(user_input):
    conversation_history.append(f"User: {user_input}")

    prompt = "\n".join(conversation_history) + "\nAssistant:"

    inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

    output = model.generate(
        **inputs,
        max_new_tokens=200,
        temperature=0.7,
        top_p=0.9,
        do_sample=True
    )

    response = tokenizer.decode(output[0], skip_special_tokens=True)
    assistant_reply = response.split("Assistant:")[-1].strip()

    conversation_history.append(f"Assistant: {assistant_reply}")

    return assistant_reply

# %%
print(chat("Hello, who are you?"))
print(chat("Can you explain what risk management is in finance?"))
print(chat("Summarize it in 3 bullet points"))
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Of course! Why don't scientists trust atoms? Because
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Absolutely! In finance, risk management refers to the identification, assessment, and prioritization of financial risks, followed by the implementation of various strategies to mitigate those risks. The goal is to minimize potential losses and maximize gains, while still maintaining a level of acceptable risk. Common types of risks managed in finance include market risk (price fluctuations), credit risk (default of borrowers), liquidity risk (inability to sell assets quickly), and operational risk (non-financial risks like fraud or system failure). Effective risk management is crucial for financial institutions, as it helps them maintain financial stability and meet regulatory requirements.
# 1. Risk management in finance involves identifying, assessing, and prioritizing financial risks.
# 2. Strategies are implemented to mitigate these risks, minimizing potential losses and maximizing gains.
# 3. Common types of risks managed include market, credit, liquidity, and operational risks.

# %%
print(chat("Can you please help me with scope of RAG?"))
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Risk management plays a significant role in supply chain management for several reasons:
# 1. Minimizing disruptions: Effective risk management helps organizations identify potential risks in their supply chains
