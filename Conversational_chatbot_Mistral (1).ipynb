# %%
# !pip install -q transformers accelerate sentencepiece bitsandbytes

# %%
from huggingface_hub import login
login()

# %%
# !pip install -U bitsandbytes>=0.46.1

import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig

model_name = "mistralai/Mistral-7B-Instruct-v0.2"

# Define the quantization configuration
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4", # or "fp4"
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_use_double_quant=True,
)

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto",
    torch_dtype=torch.float16,
    quantization_config=bnb_config # Pass the quantization config here
)
# Out:
# config.json:   0%|          | 0.00/596 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]

# %%
conversation_history = []

def chat(user_input):
    conversation_history.append(f"User: {user_input}")

    prompt = "\n".join(conversation_history) + "\nAssistant:"

    inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

    output = model.generate(
        **inputs,
        max_new_tokens=200,
        temperature=0.7,
        top_p=0.9,
        do_sample=True
    )

    response = tokenizer.decode(output[0], skip_special_tokens=True)
    assistant_reply = response.split("Assistant:")[-1].strip()

    conversation_history.append(f"Assistant: {assistant_reply}")

    return assistant_reply

# %%
print(chat("Hello, who are you?"))
print(chat("Can you explain what risk management is in finance?"))
print(chat("Summarize it in 3 bullet points"))
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Absolutely! The Eiffel Tower is an iconic landmark located in Paris, France. It was built between 1887 and 1889 as the entrance arch to the 1889 Exposition Universelle (World's Fair), which marked the centennial celebration of the French Revolution. The tower is named after the engineer Gustave Eiffel, whose company designed and built the tower. It was the tallest man-made structure in the world when it was completed, and it held this title until the Chrysler Building in New York City was finished in 1930. The Eiffel Tower is 324 meters (1,063 feet
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Absolutely! In finance, risk management refers to the identification, assessment, and prioritization of financial risks, followed by the implementation of strategies to mitigate, monitor, and control the risks that are deemed unacceptable. The goal of risk management is to protect an organization's value to its stakeholders by minimizing potential losses and maximizing gains. Common types of risks in finance include market risk (interest rate risk, foreign exchange risk, commodity risk), credit risk, operational risk, and liquidity risk. Effective risk management helps to ensure the stability and profitability of financial institutions and organizations.
# A stock represents ownership in a corporation, providing the holder with the potential for capital gains (an increase in the value of the stock) and dividend income (a portion of the company's profits distributed to shareholders). Stocks are considered higher-risk investments, as their value can fluctuate significantly based on market conditions and the financial performance of the company.
#
# A bond, on the other hand,

# %%
print(chat("Can you please help me with scope of RAG?"))
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# RAG, or Risk Assessment and Governance, is a process used in various industries to identify, evaluate, and manage risks. It involves the following steps:
#
# 1. Identification of risks: This involves identifying potential risks that could impact an organization, project, or program.
# 2. Assessment of risks: This involves evaluating the likelihood and potential impact of identified risks.
# 3. Prioritization of risks: This involves determining which risks to focus on first based on their potential impact and likelihood.
# 4. Mitigation of risks: This involves implementing strategies to reduce the likelihood or impact of identified risks.
# 5. Monitoring and reporting of risks: This involves continuously monitoring risks and reporting on their status to stakeholders.
#
# RAG is used in various industries, including finance, healthcare, and construction, to ensure compliance with regulatory requirements and to protect against potential losses. It helps organizations to make informed decisions, allocate resources effectively, and improve overall risk management
